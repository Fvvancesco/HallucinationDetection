# %%
import os

# 1. Cloniamo la repo e ci entriamo
if not os.path.exists("HallucinationDetection"):
    # !git clone https://github.com/Fvvancesco/HallucinationDetection

# %cd /content/HallucinationDetection/

# 2. Installiamo direttamente le librerie mancanti
# !pip install -q -U bitsandbytes transformers accelerate datasets

# %%
# !python main.py
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory
